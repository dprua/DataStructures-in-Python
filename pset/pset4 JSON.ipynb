# %% [markdown]
# <img src="https://github.com/idebtor/DSpy/blob/6b3676c3de29f85d2e7f30679676d1fd96d88b17/images/WelcomeToDataStructures.jpg?raw=true" width=1000>
#
# ---------

# %% [markdown]
# # PSet 4: Ch1-7 JSON
#
# Honor Code: On my honour, I pledge that I have neither received nor provided improper assistance
# in the completion of this assignment.
# Signed: 박예겸 Student Number: 21600277

# %% [markdown]
# ## JSON파일을 파이썬 객체화하기(디코딩, 역직렬화)
#
# - `json.load()`: 파일에 있는 JSON 포맷 데이터를 Python 객체로 읽어오기 (역직렬화 혹은 디코딩이라고 부르기도 합니다)
# - `json.loads()`: 메모리에 있는 JSON 형식의 문자열로 되어 있는 입력자료를 받아 파이썬 객체로 전환합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-25json_load.jpg?raw=true" width="100%">
# <center>그림1. load() and loads() 비교</center>

# %% [markdown]
# ## 파이썬 객체로 JSON파일 만들기(인코딩, 직렬화)
#
# - `json.dump()`: Python객체를 파일에 저장할 때(직렬화, 인코딩) 사용합니다.
# - `json.dumps()`: Python객체를 문자열로 출력할 때 사용합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-27json_dump.jpg?raw=true" width="100%">
#
# <center>그림2. dump() and dumps() 비교</center>

# %% [markdown]
# # JSON Exercise - JSON file
#
# ## Code 편집기로 작성한 `companies.json`작성하기
#
# 코드(텍스트) 편집기를 사용하여 아래의 내용을 가진 파일(`companies.json`)을 작성하십시오.
# ```json
# [
#     {
#         "name": "Big Corpration",
#         "numberOfEmployee": 10000,
#         "ceo": "June",
#         "rating": 3.9
#     },
#     {
#         "name": "Small Start-up",
#         "numberOfEmployee": 5,
#         "ceo": null,
#         "rating": 4.5
#     }
# ]
# ```

# %% [markdown]
# ## Code 편집기로 작성한 companies.json을 읽고 출력하기
#
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.
#
# __Sample Run:__
#
# ```json
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]
# ```

# %%
import json

with open('companies.json') as f:    
    companies = json.load(f)
    
print(companies)
# Out:
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]

# %% [markdown]
# ## 자료를 하나씩 출력하기
#
# 각 회사(`company`)별로 출력합니다
#
# __Sample Run:__
#
# ```json
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}
# ```

# %%
for company in companies:
    print(company)
# Out:
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}

# %% [markdown]
# ## 자료를 정렬하고 읽기 쉽게 포맷하기
# - 각 회사의 자료에서 `numberOfEmployee`를 삭제하십시오.
# - `indent = 2`를 추가하고 필요에 따라 `sorted_keys = True` 추가합니다.
# - 아래와 같이 출력하십시오.

# %% [markdown]
# __Sample Run:__
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
for company in companies:
    del company['numberOfEmployee']

sorted = json.dumps(companies, indent = 2, sort_keys = True)
print(sorted)
# Out:
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# ## 새로운 JSON 파일(`companies_new.json`)에 저장하기
# 아래와 같은 내용으로 JSON파일(`companies_new.json`)을 작성하십시오.
#
# __Sample Run:__ Expected JSON File
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```
# - 가독성(readability)를 높이기 위하여 `indent = 2`를 인자로 사용하는 것이 좋습니다.
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.

# %% [markdown]
# __Solution__

# %%
with open('companies_new.json','w') as f:
    json.dump(companies,f, indent=2,sort_keys=True)

# %% [markdown]
# ## 위에서 작성한 파일을 읽고 확인하기
#
# __Sample Run:__
#
# ```json
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
with open('companies_new.json') as f:
    companies = json.load(f)

for company in companies:
    print(company)
    
print(json.dumps(companies, indent = 2, sort_keys = True))
# Out:
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# # JSON Exercise: Exchange Rate Extraction
#
# 지금까지 경험해 본 JSON과 파이썬 코딩을 활용하여, 실생활 데이터를 가지고 응용하는 문제를 다루어 보도록 하겠습니다.
#
# 이제는 대부분의 자료 제공자들이 JSON 파일 형식으로 자료를 제공합니다. 여기 연습문제로 무료로 140 여개의 환율 정보를 제공하는 Website에서 JSON 파일로 원화(KRW)에 대한 각 국가의 환율 정보를 가져옵니다. 그러한 환율 정보 중에서 몇 개의 특정한 통화를 계산해보는 응용 문제를 시도해봅니다.

# %% [markdown]
# ## JSON 파일을 다운받아 파이썬 객체로 변환하기
# - 파일을 읽을 때는 `load()`를 사용하고, 문자열(String)을 읽을 때는`loads()`를 사용합니다.

# %%
import json
from urllib.request import urlopen

with urlopen("http://www.floatrates.com/daily/krw.json") as response:
    source = response.read()

rates = json.loads(source)

# %% [markdown]
# ## 파이썬 객체로 변환한 것을 출력하기
# - 가독성을 위해 `ident = 2`로 설정하는 것이 필요합니다.
#
# __Sample Run:__
# ```json
# {
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00086484208312665,
#     "date": "Sat, 4 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1156.2804580285
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#   ...
# }
# ```

# %%
print(json.dumps(rates,indent=2))
# Out:
# {
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00086024871297761,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1162.4545145074
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#     "rate": 0.00072558820750023,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1378.1921889899
#   },
#   "gbp": {
#     "code": "GBP",
#     "alphaCode": "GBP",
#     "numericCode": "826",
#     "name": "U.K. Pound Sterling",
#     "rate": 0.00062380494854346,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1603.0651926294
#   },
#   "cad": {
#     "code": "CAD",
#     "alphaCode": "CAD",
#     "numericCode": "124",
#     "name": "Canadian Dollar",
#     "rate": 0.0010843434617936,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 922.21702369642
#   },
#   "jpy": {
#     "code": "JPY",
#     "alphaCode": "JPY",
#     "numericCode": "392",
#     "name": "Japanese Yen",
#     "rate": 0.094734588344729,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 10.555806674972
#   },
#   "aud": {
#     "code": "AUD",
#     "alphaCode": "AUD",
#     "numericCode": "036",
#     "name": "Australian Dollar",
#     "rate": 0.0011631982603228,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 859.69867228179
#   },
#   "chf": {
#     "code": "CHF",
#     "alphaCode": "CHF",
#     "numericCode": "756",
#     "name": "Swiss Franc",
#     "rate": 0.00078855420624272,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1268.1436381714
#   },
#   "cop": {
#     "code": "COP",
#     "alphaCode": "COP",
#     "numericCode": "170",
#     "name": "Colombian Peso",
#     "rate": 3.2513069501533,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.30756862250513
#   },
#   "bzd": {
#     "code": "BZD",
#     "alphaCode": "BZD",
#     "numericCode": "084",
#     "name": "Belize dollar",
#     "rate": 0.0017235330115543,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 580.20356633506
#   },
#   "gnf": {
#     "code": "GNF",
#     "alphaCode": "GNF",
#     "numericCode": "324",
#     "name": "Guinean franc",
#     "rate": 8.3694939361587,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.11948153707116
#   },
#   "sll": {
#     "code": "SLL",
#     "alphaCode": "SLL",
#     "numericCode": "694",
#     "name": "Sierra Leonean leone",
#     "rate": 8.8445192676703,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.11306437011849
#   },
#   "kes": {
#     "code": "KES",
#     "alphaCode": "KES",
#     "numericCode": "404",
#     "name": "Kenyan shilling",
#     "rate": 0.093971747330519,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 10.641496283801
#   },
#   "aed": {
#     "code": "AED",
#     "alphaCode": "AED",
#     "numericCode": "784",
#     "name": "U.A.E Dirham",
#     "rate": 0.0031458180338181,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 317.88234069798
#   },
#   "php": {
#     "code": "PHP",
#     "alphaCode": "PHP",
#     "numericCode": "608",
#     "name": "Philippine Peso",
#     "rate": 0.043192181334159,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 23.152338435131
#   },
#   "ils": {
#     "code": "ILS",
#     "alphaCode": "ILS",
#     "numericCode": "376",
#     "name": "Israeli New Sheqel",
#     "rate": 0.0027575518835112,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 362.64050224386
#   },
#   "mro": {
#     "code": "MRO",
#     "alphaCode": "MRO",
#     "numericCode": "478",
#     "name": "Mauritanian Ouguiya",
#     "rate": 0.031192581970241,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 32.058904291861
#   },
#   "bob": {
#     "code": "BOB",
#     "alphaCode": "BOB",
#     "numericCode": "068",
#     "name": "Bolivian Boliviano",
#     "rate": 0.005902549287063,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 169.41832272231
#   },
#   "gyd": {
#     "code": "GYD",
#     "alphaCode": "GYD",
#     "numericCode": "328",
#     "name": "Guyanese dollar",
#     "rate": 0.17889204225869,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 5.5899635745337
#   },
#   "rwf": {
#     "code": "RWF",
#     "alphaCode": "RWF",
#     "numericCode": "646",
#     "name": "Rwandan franc",
#     "rate": 0.86299370491516,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1.1587570040251
#   },
#   "mzn": {
#     "code": "MZN",
#     "alphaCode": "MZN",
#     "numericCode": "943",
#     "name": "Mozambican metical",
#     "rate": 0.054815278543352,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 18.243088908307
#   },
#   "ugx": {
#     "code": "UGX",
#     "alphaCode": "UGX",
#     "numericCode": "800",
#     "name": "Ugandan shilling",
#     "rate": 3.0216732493426,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.3309424671306
#   },
#   "cny": {
#     "code": "CNY",
#     "alphaCode": "CNY",
#     "numericCode": "156",
#     "name": "Chinese Yuan",
#     "rate": 0.005561077716566,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 179.8212596492
#   },
#   "sar": {
#     "code": "SAR",
#     "alphaCode": "SAR",
#     "numericCode": "682",
#     "name": "Saudi Riyal",
#     "rate": 0.0032263367920917,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 309.94904265766
#   },
#   "myr": {
#     "code": "MYR",
#     "alphaCode": "MYR",
#     "numericCode": "458",
#     "name": "Malaysian Ringgit",
#     "rate": 0.0035682074288339,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 280.25276555371
#   },
#   "kzt": {
#     "code": "KZT",
#     "alphaCode": "KZT",
#     "numericCode": "398",
#     "name": "Kazakhstani Tenge",
#     "rate": 0.36657133209901,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.7279820117791
#   },
#   "tjs": {
#     "code": "TJS",
#     "alphaCode": "TJS",
#     "numericCode": "972",
#     "name": "Tajikistan Ruble",
#     "rate": 0.0097168148045556,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 102.91438296541
#   },
#   "afn": {
#     "code": "AFN",
#     "alphaCode": "AFN",
#     "numericCode": "971",
#     "name": "Afghan afghani",
#     "rate": 0.075955624571489,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 13.165581951851
#   },
#   "nad": {
#     "code": "NAD",
#     "alphaCode": "NAD",
#     "numericCode": "516",
#     "name": "Namibian dollar",
#     "rate": 0.012353613171152,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 80.94797741726
#   },
#   "syp": {
#     "code": "SYP",
#     "alphaCode": "SYP",
#     "numericCode": "760",
#     "name": "Syrian pound",
#     "rate": 2.1816480860254,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.45836906804792
#   },
#   "top": {
#     "code": "TOP",
#     "alphaCode": "TOP",
#     "numericCode": "776",
#     "name": "Tongan pa\u02bbanga",
#     "rate": 0.001922947543212,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 520.03498666929
#   },
#   "vuv": {
#     "code": "VUV",
#     "alphaCode": "VUV",
#     "numericCode": "548",
#     "name": "Vanuatu vatu",
#     "rate": 0.094804801235239,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 10.547988993919
#   },
#   "idr": {
#     "code": "IDR",
#     "alphaCode": "IDR",
#     "numericCode": "360",
#     "name": "Indonesian Rupiah",
#     "rate": 12.21447396309,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.081870083232551
#   },
#   "tnd": {
#     "code": "TND",
#     "alphaCode": "TND",
#     "numericCode": "788",
#     "name": "Tunisian Dinar",
#     "rate": 0.0023810819904794,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 419.97713812395
#   },
#   "xof": {
#     "code": "XOF",
#     "alphaCode": "XOF",
#     "numericCode": "952",
#     "name": "West African CFA Franc",
#     "rate": 0.47613312091382,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.100252967239
#   },
#   "uah": {
#     "code": "UAH",
#     "alphaCode": "UAH",
#     "numericCode": "980",
#     "name": "Ukrainian Hryvnia",
#     "rate": 0.022998025264125,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 43.481994150164
#   },
#   "etb": {
#     "code": "ETB",
#     "alphaCode": "ETB",
#     "numericCode": "230",
#     "name": "Ethiopian birr",
#     "rate": 0.039050980060122,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 25.607551934943
#   },
#   "xcd": {
#     "code": "XCD",
#     "alphaCode": "XCD",
#     "numericCode": "951",
#     "name": "East Caribbean Dollar",
#     "rate": 0.0023176148222649,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 431.47808272245
#   },
#   "lak": {
#     "code": "LAK",
#     "alphaCode": "LAK",
#     "numericCode": "418",
#     "name": "Lao kip",
#     "rate": 8.2016845339301,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.12192617210075
#   },
#   "bwp": {
#     "code": "BWP",
#     "alphaCode": "BWP",
#     "numericCode": "072",
#     "name": "Botswana Pula",
#     "rate": 0.0094389158610852,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 105.94437059481
#   },
#   "kwd": {
#     "code": "KWD",
#     "alphaCode": "KWD",
#     "numericCode": "414",
#     "name": "Kuwaiti Dinar",
#     "rate": 0.00025809462430035,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 3874.5479597293
#   },
#   "czk": {
#     "code": "CZK",
#     "alphaCode": "CZK",
#     "numericCode": "203",
#     "name": "Czech Koruna",
#     "rate": 0.018434536547324,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 54.246007076602
#   },
#   "pgk": {
#     "code": "PGK",
#     "alphaCode": "PGK",
#     "numericCode": "598",
#     "name": "Papua New Guinean kina",
#     "rate": 0.0030169373973098,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 331.46196566481
#   },
#   "rsd": {
#     "code": "RSD",
#     "alphaCode": "RSD",
#     "numericCode": "941",
#     "name": "Serbian Dinar",
#     "rate": 0.084990038740583,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 11.766084764972
#   },
#   "gmd": {
#     "code": "GMD",
#     "alphaCode": "GMD",
#     "numericCode": "270",
#     "name": "Gambian dalasi",
#     "rate": 0.04452343032705,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 22.460084334348
#   },
#   "awg": {
#     "code": "AWG",
#     "alphaCode": "AWG",
#     "numericCode": "533",
#     "name": "Aruban florin",
#     "rate": 0.0015477072119931,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 646.11703832035
#   },
#   "aoa": {
#     "code": "AOA",
#     "alphaCode": "AOA",
#     "numericCode": "973",
#     "name": "Angolan kwanza",
#     "rate": 0.54541202150636,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1.8334762721916
#   },
#   "khr": {
#     "code": "KHR",
#     "alphaCode": "KHR",
#     "numericCode": "116",
#     "name": "Cambodian riel",
#     "rate": 3.4887762569704,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.28663345721929
#   },
#   "nok": {
#     "code": "NOK",
#     "alphaCode": "NOK",
#     "numericCode": "578",
#     "name": "Norwegian Krone",
#     "rate": 0.0074625880101422,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 134.00176971326
#   },
#   "mad": {
#     "code": "MAD",
#     "alphaCode": "MAD",
#     "numericCode": "504",
#     "name": "Moroccan Dirham",
#     "rate": 0.0075956446136905,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 131.65439549365
#   },
#   "ron": {
#     "code": "RON",
#     "alphaCode": "RON",
#     "numericCode": "946",
#     "name": "Romanian New Leu",
#     "rate": 0.0035896855639341,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 278.57593156546
#   },
#   "byn": {
#     "code": "BYN",
#     "alphaCode": "BYN",
#     "numericCode": "933",
#     "name": "Belarussian Ruble",
#     "rate": 0.0021652026921768,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 461.85052494769
#   },
#   "clp": {
#     "code": "CLP",
#     "alphaCode": "CLP",
#     "numericCode": "152",
#     "name": "Chilean Peso",
#     "rate": 0.66804858870066,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1.4968971073571
#   },
#   "bsd": {
#     "code": "BSD",
#     "alphaCode": "BSD",
#     "numericCode": "044",
#     "name": "Bahamian Dollar",
#     "rate": 0.0008558167605623,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1168.4744282678
#   },
#   "djf": {
#     "code": "DJF",
#     "alphaCode": "DJF",
#     "numericCode": "262",
#     "name": "Djiboutian franc",
#     "rate": 0.15222216620328,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 6.5693454832628
#   },
#   "hnl": {
#     "code": "HNL",
#     "alphaCode": "HNL",
#     "numericCode": "340",
#     "name": "Honduran Lempira",
#     "rate": 0.020414673294062,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 48.984374405388
#   },
#   "scr": {
#     "code": "SCR",
#     "alphaCode": "SCR",
#     "numericCode": "690",
#     "name": "Seychelles rupee",
#     "rate": 0.011059385363427,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 90.42093815692
#   },
#   "bhd": {
#     "code": "BHD",
#     "alphaCode": "BHD",
#     "numericCode": "048",
#     "name": "Bahrain Dinar",
#     "rate": 0.00032337465059042,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 3092.388343286
#   },
#   "omr": {
#     "code": "OMR",
#     "alphaCode": "OMR",
#     "numericCode": "512",
#     "name": "Omani Rial",
#     "rate": 0.00033038855718959,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 3026.7392082412
#   },
#   "rub": {
#     "code": "RUB",
#     "alphaCode": "RUB",
#     "numericCode": "643",
#     "name": "Russian Rouble",
#     "rate": 0.06303992629721,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 15.862962708512
#   },
#   "lyd": {
#     "code": "LYD",
#     "alphaCode": "LYD",
#     "numericCode": "434",
#     "name": "Libyan Dinar",
#     "rate": 0.0038620225032593,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 258.93168648191
#   },
#   "uyu": {
#     "code": "UYU",
#     "alphaCode": "UYU",
#     "numericCode": "858",
#     "name": "Uruguayan Peso",
#     "rate": 0.036447796086449,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 27.436501170829
#   },
#   "fjd": {
#     "code": "FJD",
#     "alphaCode": "FJD",
#     "numericCode": "242",
#     "name": "Fiji Dollar",
#     "rate": 0.0017874547351093,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 559.45472652143
#   },
#   "cdf": {
#     "code": "CDF",
#     "alphaCode": "CDF",
#     "numericCode": "976",
#     "name": "Congolese franc",
#     "rate": 1.6982211359824,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.58885146275224
#   },
#   "lsl": {
#     "code": "LSL",
#     "alphaCode": "LSL",
#     "numericCode": "426",
#     "name": "Lesotho loti",
#     "rate": 0.012353613171152,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 80.94797741726
#   },
#   "tzs": {
#     "code": "TZS",
#     "alphaCode": "TZS",
#     "numericCode": "834",
#     "name": "Tanzanian shilling",
#     "rate": 1.9833164418413,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.5042059748527
#   },
#   "bbd": {
#     "code": "BBD",
#     "alphaCode": "BBD",
#     "numericCode": "052",
#     "name": "Barbadian Dollar",
#     "rate": 0.0017205270044099,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 581.21726508034
#   },
#   "bdt": {
#     "code": "BDT",
#     "alphaCode": "BDT",
#     "numericCode": "050",
#     "name": "Bangladeshi taka",
#     "rate": 0.072915729839264,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 13.714461916577
#   },
#   "qar": {
#     "code": "QAR",
#     "alphaCode": "QAR",
#     "numericCode": "634",
#     "name": "Qatari Rial",
#     "rate": 0.0031263807851325,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 319.85867004924
#   },
#   "mxn": {
#     "code": "MXN",
#     "alphaCode": "MXN",
#     "numericCode": "484",
#     "name": "Mexican Peso",
#     "rate": 0.017159396866204,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 58.277106578818
#   },
#   "amd": {
#     "code": "AMD",
#     "alphaCode": "AMD",
#     "numericCode": "051",
#     "name": "Armenia Dram",
#     "rate": 0.42305779567508,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.3637432289938
#   },
#   "nio": {
#     "code": "NIO",
#     "alphaCode": "NIO",
#     "numericCode": "558",
#     "name": "Nicaraguan C\u00f3rdoba",
#     "rate": 0.030119974212356,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 33.200559633606
#   },
#   "lrd": {
#     "code": "LRD",
#     "alphaCode": "LRD",
#     "numericCode": "430",
#     "name": "Liberian dollar",
#     "rate": 0.14674762910485,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 6.814420144979
#   },
#   "sdg": {
#     "code": "SDG",
#     "alphaCode": "SDG",
#     "numericCode": "938",
#     "name": "Sudanese pound",
#     "rate": 0.37614622172851,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.658540594678
#   },
#   "mru": {
#     "code": "MRU",
#     "alphaCode": "MRU",
#     "numericCode": "929",
#     "name": "Mauritanian ouguiya",
#     "rate": 0.030901530963533,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 32.360856204183
#   },
#   "mnt": {
#     "code": "MNT",
#     "alphaCode": "MNT",
#     "numericCode": "496",
#     "name": "Mongolian togrog",
#     "rate": 2.4366881079956,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.41039310559224
#   },
#   "brl": {
#     "code": "BRL",
#     "alphaCode": "BRL",
#     "numericCode": "986",
#     "name": "Brazilian Real",
#     "rate": 0.0044460865824272,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 224.91689746943
#   },
#   "hkd": {
#     "code": "HKD",
#     "alphaCode": "HKD",
#     "numericCode": "344",
#     "name": "Hong Kong Dollar",
#     "rate": 0.0066887254514497,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 149.50531416763
#   },
#   "thb": {
#     "code": "THB",
#     "alphaCode": "THB",
#     "numericCode": "764",
#     "name": "Thai Baht",
#     "rate": 0.027913438404323,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 35.825038302882
#   },
#   "xaf": {
#     "code": "XAF",
#     "alphaCode": "XAF",
#     "numericCode": "950",
#     "name": "Central African CFA Franc",
#     "rate": 0.476361496196,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.0992460725427
#   },
#   "mdl": {
#     "code": "MDL",
#     "alphaCode": "MDL",
#     "numericCode": "498",
#     "name": "Moldova Lei",
#     "rate": 0.015154159386944,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 65.988483720287
#   },
#   "uzs": {
#     "code": "UZS",
#     "alphaCode": "UZS",
#     "numericCode": "860",
#     "name": "Uzbekistan Sum",
#     "rate": 9.1489638675039,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.1093019946829
#   },
#   "pab": {
#     "code": "PAB",
#     "alphaCode": "PAB",
#     "numericCode": "590",
#     "name": "Panamanian Balboa",
#     "rate": 0.0008558167605623,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1168.4744282678
#   },
#   "ttd": {
#     "code": "TTD",
#     "alphaCode": "TTD",
#     "numericCode": "780",
#     "name": "Trinidad Tobago Dollar",
#     "rate": 0.005808434733827,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 172.1634219588
#   },
#   "htg": {
#     "code": "HTG",
#     "alphaCode": "HTG",
#     "numericCode": "332",
#     "name": "Haitian gourde",
#     "rate": 0.083481431863218,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 11.978711644986
#   },
#   "cup": {
#     "code": "CUP",
#     "alphaCode": "CUP",
#     "numericCode": "192",
#     "name": "Cuban peso",
#     "rate": 0.0008558167605623,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1168.4744282678
#   },
#   "dkk": {
#     "code": "DKK",
#     "alphaCode": "DKK",
#     "numericCode": "208",
#     "name": "Danish Krone",
#     "rate": 0.0053928117595289,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 185.43202407038
#   },
#   "jod": {
#     "code": "JOD",
#     "alphaCode": "JOD",
#     "numericCode": "400",
#     "name": "Jordanian Dinar",
#     "rate": 0.00060899890978304,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1642.0390643331
#   },
#   "bgn": {
#     "code": "BGN",
#     "alphaCode": "BGN",
#     "numericCode": "975",
#     "name": "Bulgarian Lev",
#     "rate": 0.0014183373224815,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 705.05089596772
#   },
#   "vnd": {
#     "code": "VND",
#     "alphaCode": "VND",
#     "numericCode": "704",
#     "name": "Vietnamese Dong",
#     "rate": 19.533543623147,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.051193988110534
#   },
#   "iqd": {
#     "code": "IQD",
#     "alphaCode": "IQD",
#     "numericCode": "368",
#     "name": "Iraqi dinar",
#     "rate": 1.2483467520486,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.80105947995532
#   },
#   "svc": {
#     "code": "SVC",
#     "alphaCode": "SVC",
#     "numericCode": "222",
#     "name": "Salvadoran colon",
#     "rate": 0.0074850689136278,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 133.59930436704
#   },
#   "cve": {
#     "code": "CVE",
#     "alphaCode": "CVE",
#     "numericCode": "132",
#     "name": "Cape Verde escudo",
#     "rate": 0.080207650221524,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 12.467638650903
#   },
#   "zmw": {
#     "code": "ZMW",
#     "alphaCode": "ZMW",
#     "numericCode": "967",
#     "name": "Zambian kwacha",
#     "rate": 0.013658063977621,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 73.216819136188
#   },
#   "yer": {
#     "code": "YER",
#     "alphaCode": "YER",
#     "numericCode": "886",
#     "name": "Yemeni rial",
#     "rate": 0.21402695415553,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 4.6723087003018
#   },
#   "lkr": {
#     "code": "LKR",
#     "alphaCode": "LKR",
#     "numericCode": "144",
#     "name": "Sri Lanka Rupee",
#     "rate": 0.17153357825824,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 5.8297623716245
#   },
#   "pln": {
#     "code": "PLN",
#     "alphaCode": "PLN",
#     "numericCode": "985",
#     "name": "Polish Zloty",
#     "rate": 0.0032768829625488,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 305.16805495616
#   },
#   "pen": {
#     "code": "PEN",
#     "alphaCode": "PEN",
#     "numericCode": "604",
#     "name": "Peruvian Nuevo Sol",
#     "rate": 0.003529242849197,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 283.34689414403
#   },
#   "ars": {
#     "code": "ARS",
#     "alphaCode": "ARS",
#     "numericCode": "032",
#     "name": "Argentine Peso",
#     "rate": 0.083886881986645,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 11.920814987011
#   },
#   "stn": {
#     "code": "STN",
#     "alphaCode": "STN",
#     "numericCode": "930",
#     "name": "S\u00e3o Tom\u00e9 and Pr\u00edncipe Dobra",
#     "rate": 0.017921534113024,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 55.798794550366
#   },
#   "xpf": {
#     "code": "XPF",
#     "alphaCode": "XPF",
#     "numericCode": "953",
#     "name": "CFP Franc",
#     "rate": 0.086424722805703,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 11.570763174424
#   },
#   "all": {
#     "code": "ALL",
#     "alphaCode": "ALL",
#     "numericCode": "008",
#     "name": "Albanian lek",
#     "rate": 0.08826865536597,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 11.329049885873
#   },
#   "mur": {
#     "code": "MUR",
#     "alphaCode": "MUR",
#     "numericCode": "480",
#     "name": "Mauritian Rupee",
#     "rate": 0.036199912931838,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 27.624375834354
#   },
#   "dop": {
#     "code": "DOP",
#     "alphaCode": "DOP",
#     "numericCode": "214",
#     "name": "Dominican Peso",
#     "rate": 0.048730473181428,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 20.521040218036
#   },
#   "nzd": {
#     "code": "NZD",
#     "alphaCode": "NZD",
#     "numericCode": "554",
#     "name": "New Zealand Dollar",
#     "rate": 0.0012101918279586,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 826.31528068312
#   },
#   "hrk": {
#     "code": "HRK",
#     "alphaCode": "HRK",
#     "numericCode": "191",
#     "name": "Croatian Kuna",
#     "rate": 0.0054240985760756,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 184.36243109791
#   },
#   "dzd": {
#     "code": "DZD",
#     "alphaCode": "DZD",
#     "numericCode": "012",
#     "name": "Algerian Dinar",
#     "rate": 0.11583572310129,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 8.6329154187228
#   },
#   "pyg": {
#     "code": "PYG",
#     "alphaCode": "PYG",
#     "numericCode": "600",
#     "name": "Paraguayan Guaran\u00ed",
#     "rate": 5.9392932218434,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.16837020208435
#   },
#   "bnd": {
#     "code": "BND",
#     "alphaCode": "BND",
#     "numericCode": "096",
#     "name": "Brunei Dollar",
#     "rate": 0.0011511034960913,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 868.73161570232
#   },
#   "kmf": {
#     "code": "KMF",
#     "alphaCode": "KMF",
#     "numericCode": "174",
#     "name": "\tComoro franc",
#     "rate": 0.35671159025922,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.8033852201811
#   },
#   "szl": {
#     "code": "SZL",
#     "alphaCode": "SZL",
#     "numericCode": "748",
#     "name": "Swazi lilangeni",
#     "rate": 0.012353613171152,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 80.94797741726
#   },
#   "sos": {
#     "code": "SOS",
#     "alphaCode": "SOS",
#     "numericCode": "706",
#     "name": "Somali shilling",
#     "rate": 0.49463000741206,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.02171316947
#   },
#   "ang": {
#     "code": "ANG",
#     "alphaCode": "ANG",
#     "numericCode": "532",
#     "name": "Neth. Antillean Guilder",
#     "rate": 0.0015274586348029,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 654.68221345913
#   },
#   "pkr": {
#     "code": "PKR",
#     "alphaCode": "PKR",
#     "numericCode": "586",
#     "name": "Pakistani Rupee",
#     "rate": 0.1429097577519,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 6.9974228193433
#   },
#   "azn": {
#     "code": "AZN",
#     "alphaCode": "AZN",
#     "numericCode": "944",
#     "name": "Azerbaijan Manat",
#     "rate": 0.0014567688687936,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 686.4506933266
#   },
#   "crc": {
#     "code": "CRC",
#     "alphaCode": "CRC",
#     "numericCode": "188",
#     "name": "Costa Rican Col\u00f3n",
#     "rate": 0.53449955676547,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1.8709089415369
#   },
#   "jmd": {
#     "code": "JMD",
#     "alphaCode": "JMD",
#     "numericCode": "388",
#     "name": "Jamaican Dollar",
#     "rate": 0.12934672446791,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 7.7311582810748
#   },
#   "ssp": {
#     "code": "SSP",
#     "alphaCode": "SSP",
#     "numericCode": "728",
#     "name": "South Sudanese pound",
#     "rate": 0.15208775057109,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 6.575151491458
#   },
#   "ern": {
#     "code": "ERN",
#     "alphaCode": "ERN",
#     "numericCode": "232",
#     "name": "Eritrean nakfa",
#     "rate": 0.012893901217644,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 77.556046313709
#   },
#   "wst": {
#     "code": "WST",
#     "alphaCode": "WST",
#     "numericCode": "882",
#     "name": "Samoan tala",
#     "rate": 0.002183686193139,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 457.94125691775
#   },
#   "egp": {
#     "code": "EGP",
#     "alphaCode": "EGP",
#     "numericCode": "818",
#     "name": "Egyptian Pound",
#     "rate": 0.013528610919784,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 73.917418863574
#   },
#   "sgd": {
#     "code": "SGD",
#     "alphaCode": "SGD",
#     "numericCode": "702",
#     "name": "Singapore Dollar",
#     "rate": 0.0011571295342513,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 864.20748101206
#   },
#   "zar": {
#     "code": "ZAR",
#     "alphaCode": "ZAR",
#     "numericCode": "710",
#     "name": "South African Rand",
#     "rate": 0.012311425110795,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 81.225365138533
#   },
#   "kgs": {
#     "code": "KGS",
#     "alphaCode": "KGS",
#     "numericCode": "417",
#     "name": "Kyrgyzstan Som",
#     "rate": 0.072664415972595,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 13.761894135049
#   },
#   "tmt": {
#     "code": "TMT",
#     "alphaCode": "TMT",
#     "numericCode": "934",
#     "name": "New Turkmenistan Manat",
#     "rate": 0.0029991112770111,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 333.43210959368
#   },
#   "mga": {
#     "code": "MGA",
#     "alphaCode": "MGA",
#     "numericCode": "969",
#     "name": "Malagasy ariary",
#     "rate": 3.352942755162,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.29824547360985
#   },
#   "srd": {
#     "code": "SRD",
#     "alphaCode": "SRD",
#     "numericCode": "968",
#     "name": "Surinamese dollar",
#     "rate": 0.018405355056457,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 54.332013532615
#   },
#   "ghs": {
#     "code": "GHS",
#     "alphaCode": "GHS",
#     "numericCode": "936",
#     "name": "Ghanaian Cedi",
#     "rate": 0.0051648865672949,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 193.61509434345
#   },
#   "mop": {
#     "code": "MOP",
#     "alphaCode": "MOP",
#     "numericCode": "446",
#     "name": "Macanese pataca",
#     "rate": 0.0068533447728546,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 145.91415332859
#   },
#   "bam": {
#     "code": "BAM",
#     "alphaCode": "BAM",
#     "numericCode": "977",
#     "name": "Bosnia and Herzegovina convertible mark",
#     "rate": 0.0014200356385499,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 704.20767821094
#   },
#   "inr": {
#     "code": "INR",
#     "alphaCode": "INR",
#     "numericCode": "356",
#     "name": "Indian Rupee",
#     "rate": 0.063180021353535,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 15.827788256106
#   },
#   "try": {
#     "code": "TRY",
#     "alphaCode": "TRY",
#     "numericCode": "949",
#     "name": "Turkish Lira",
#     "rate": 0.0071702448053744,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 139.46525218364
#   },
#   "twd": {
#     "code": "TWD",
#     "alphaCode": "TWD",
#     "numericCode": "901",
#     "name": "New Taiwan Dollar ",
#     "rate": 0.023773824204503,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 42.06306866737
#   },
#   "irr": {
#     "code": "IRR",
#     "alphaCode": "IRR",
#     "numericCode": "364",
#     "name": "Iranian rial",
#     "rate": 35.918544173402,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.027840772030524
#   },
#   "ves": {
#     "code": "VES",
#     "alphaCode": "VES",
#     "numericCode": "928",
#     "name": "Venezuelan Bolivar",
#     "rate": 3518.7872355249,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.00028418882218971
#   },
#   "sbd": {
#     "code": "SBD",
#     "alphaCode": "SBD",
#     "numericCode": "090",
#     "name": "Solomon Islands dollar",
#     "rate": 0.006819070908602,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 146.64754383747
#   },
#   "mwk": {
#     "code": "MWK",
#     "alphaCode": "MWK",
#     "numericCode": "454",
#     "name": "Malawian kwacha",
#     "rate": 0.69479238408453,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1.4392788736705
#   },
#   "gtq": {
#     "code": "GTQ",
#     "alphaCode": "GTQ",
#     "numericCode": "320",
#     "name": "Guatemalan Quetzal",
#     "rate": 0.0066164013931221,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 151.13956070433
#   },
#   "lbp": {
#     "code": "LBP",
#     "alphaCode": "LBP",
#     "numericCode": "422",
#     "name": "Lebanese Pound",
#     "rate": 1.2910126788522,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.77458573132612
#   },
#   "huf": {
#     "code": "HUF",
#     "alphaCode": "HUF",
#     "numericCode": "348",
#     "name": "Hungarian Forint",
#     "rate": 0.25256397283425,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 3.959392896691
#   },
#   "ngn": {
#     "code": "NGN",
#     "alphaCode": "NGN",
#     "numericCode": "566",
#     "name": "Nigerian Naira",
#     "rate": 0.35223702181118,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 2.8389974309289
#   },
#   "gel": {
#     "code": "GEL",
#     "alphaCode": "GEL",
#     "numericCode": "981",
#     "name": "Georgian lari",
#     "rate": 0.0026589463942476,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 376.08881554115
#   },
#   "mkd": {
#     "code": "MKD",
#     "alphaCode": "MKD",
#     "numericCode": "807",
#     "name": "Macedonian denar",
#     "rate": 0.044624822781531,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 22.409052578106
#   },
#   "bif": {
#     "code": "BIF",
#     "alphaCode": "BIF",
#     "numericCode": "108",
#     "name": "Burundian franc",
#     "rate": 1.6973403158912,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.58915704213092
#   },
#   "mmk": {
#     "code": "MMK",
#     "alphaCode": "MMK",
#     "numericCode": "104",
#     "name": "Myanma Kyat",
#     "rate": 1.40751489421,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 0.71047205547426
#   },
#   "mvr": {
#     "code": "MVR",
#     "alphaCode": "MVR",
#     "numericCode": "462",
#     "name": "Maldivian rufiyaa",
#     "rate": 0.013216769503385,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 75.661454165775
#   },
#   "sek": {
#     "code": "SEK",
#     "alphaCode": "SEK",
#     "numericCode": "752",
#     "name": "Swedish Krona",
#     "rate": 0.0073749462111487,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 135.59420928227
#   },
#   "npr": {
#     "code": "NPR",
#     "alphaCode": "NPR",
#     "numericCode": "524",
#     "name": "Nepalese Rupee",
#     "rate": 0.10028978966723,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 9.9711047686716
#   },
#   "isk": {
#     "code": "ISK",
#     "alphaCode": "ISK",
#     "numericCode": "352",
#     "name": "Icelandic Krona",
#     "rate": 0.10937377307483,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 9.1429597049364
#   },
#   "gip": {
#     "code": "GIP",
#     "alphaCode": "GIP",
#     "numericCode": "292",
#     "name": "Gibraltar pound",
#     "rate": 0.00062200283932689,
#     "date": "Tue, 7 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1607.7097028724
#   }
# }

# %% [markdown]
# ## 파이썬 객체 `rates`의 `type`, 자료(통화)의 수, 각 환율 자료 출력하기
#
# __Sample Run:__
# ```
# <class 'dict'>
# 149
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00086484208312665, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1156.2804580285}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00072856130060557, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1372.5680998549}
# ```

# %%
print(type(rates))
print(len(rates))
for rate in rates:
    print(rates[rate])
# Out:
# <class 'dict'>
# 149
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00086024871297761, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1162.4545145074}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00072558820750023, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1378.1921889899}
# {'code': 'GBP', 'alphaCode': 'GBP', 'numericCode': '826', 'name': 'U.K. Pound Sterling', 'rate': 0.00062380494854346, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1603.0651926294}
# {'code': 'CAD', 'alphaCode': 'CAD', 'numericCode': '124', 'name': 'Canadian Dollar', 'rate': 0.0010843434617936, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 922.21702369642}
# {'code': 'JPY', 'alphaCode': 'JPY', 'numericCode': '392', 'name': 'Japanese Yen', 'rate': 0.094734588344729, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 10.555806674972}
# {'code': 'AUD', 'alphaCode': 'AUD', 'numericCode': '036', 'name': 'Australian Dollar', 'rate': 0.0011631982603228, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 859.69867228179}
# {'code': 'CHF', 'alphaCode': 'CHF', 'numericCode': '756', 'name': 'Swiss Franc', 'rate': 0.00078855420624272, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1268.1436381714}
# {'code': 'COP', 'alphaCode': 'COP', 'numericCode': '170', 'name': 'Colombian Peso', 'rate': 3.2513069501533, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.30756862250513}
# {'code': 'BZD', 'alphaCode': 'BZD', 'numericCode': '084', 'name': 'Belize dollar', 'rate': 0.0017235330115543, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 580.20356633506}
# {'code': 'GNF', 'alphaCode': 'GNF', 'numericCode': '324', 'name': 'Guinean franc', 'rate': 8.3694939361587, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.11948153707116}
# {'code': 'SLL', 'alphaCode': 'SLL', 'numericCode': '694', 'name': 'Sierra Leonean leone', 'rate': 8.8445192676703, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.11306437011849}
# {'code': 'KES', 'alphaCode': 'KES', 'numericCode': '404', 'name': 'Kenyan shilling', 'rate': 0.093971747330519, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 10.641496283801}
# {'code': 'AED', 'alphaCode': 'AED', 'numericCode': '784', 'name': 'U.A.E Dirham', 'rate': 0.0031458180338181, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 317.88234069798}
# {'code': 'PHP', 'alphaCode': 'PHP', 'numericCode': '608', 'name': 'Philippine Peso', 'rate': 0.043192181334159, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 23.152338435131}
# {'code': 'ILS', 'alphaCode': 'ILS', 'numericCode': '376', 'name': 'Israeli New Sheqel', 'rate': 0.0027575518835112, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 362.64050224386}
# {'code': 'MRO', 'alphaCode': 'MRO', 'numericCode': '478', 'name': 'Mauritanian Ouguiya', 'rate': 0.031192581970241, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 32.058904291861}
# {'code': 'BOB', 'alphaCode': 'BOB', 'numericCode': '068', 'name': 'Bolivian Boliviano', 'rate': 0.005902549287063, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 169.41832272231}
# {'code': 'GYD', 'alphaCode': 'GYD', 'numericCode': '328', 'name': 'Guyanese dollar', 'rate': 0.17889204225869, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 5.5899635745337}
# {'code': 'RWF', 'alphaCode': 'RWF', 'numericCode': '646', 'name': 'Rwandan franc', 'rate': 0.86299370491516, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1.1587570040251}
# {'code': 'MZN', 'alphaCode': 'MZN', 'numericCode': '943', 'name': 'Mozambican metical', 'rate': 0.054815278543352, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 18.243088908307}
# {'code': 'UGX', 'alphaCode': 'UGX', 'numericCode': '800', 'name': 'Ugandan shilling', 'rate': 3.0216732493426, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.3309424671306}
# {'code': 'CNY', 'alphaCode': 'CNY', 'numericCode': '156', 'name': 'Chinese Yuan', 'rate': 0.005561077716566, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 179.8212596492}
# {'code': 'SAR', 'alphaCode': 'SAR', 'numericCode': '682', 'name': 'Saudi Riyal', 'rate': 0.0032263367920917, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 309.94904265766}
# {'code': 'MYR', 'alphaCode': 'MYR', 'numericCode': '458', 'name': 'Malaysian Ringgit', 'rate': 0.0035682074288339, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 280.25276555371}
# {'code': 'KZT', 'alphaCode': 'KZT', 'numericCode': '398', 'name': 'Kazakhstani Tenge', 'rate': 0.36657133209901, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.7279820117791}
# {'code': 'TJS', 'alphaCode': 'TJS', 'numericCode': '972', 'name': 'Tajikistan Ruble', 'rate': 0.0097168148045556, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 102.91438296541}
# {'code': 'AFN', 'alphaCode': 'AFN', 'numericCode': '971', 'name': 'Afghan afghani', 'rate': 0.075955624571489, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 13.165581951851}
# {'code': 'NAD', 'alphaCode': 'NAD', 'numericCode': '516', 'name': 'Namibian dollar', 'rate': 0.012353613171152, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 80.94797741726}
# {'code': 'SYP', 'alphaCode': 'SYP', 'numericCode': '760', 'name': 'Syrian pound', 'rate': 2.1816480860254, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.45836906804792}
# {'code': 'TOP', 'alphaCode': 'TOP', 'numericCode': '776', 'name': 'Tongan paʻanga', 'rate': 0.001922947543212, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 520.03498666929}
# {'code': 'VUV', 'alphaCode': 'VUV', 'numericCode': '548', 'name': 'Vanuatu vatu', 'rate': 0.094804801235239, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 10.547988993919}
# {'code': 'IDR', 'alphaCode': 'IDR', 'numericCode': '360', 'name': 'Indonesian Rupiah', 'rate': 12.21447396309, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.081870083232551}
# {'code': 'TND', 'alphaCode': 'TND', 'numericCode': '788', 'name': 'Tunisian Dinar', 'rate': 0.0023810819904794, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 419.97713812395}
# {'code': 'XOF', 'alphaCode': 'XOF', 'numericCode': '952', 'name': 'West African CFA Franc', 'rate': 0.47613312091382, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.100252967239}
# {'code': 'UAH', 'alphaCode': 'UAH', 'numericCode': '980', 'name': 'Ukrainian Hryvnia', 'rate': 0.022998025264125, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 43.481994150164}
# {'code': 'ETB', 'alphaCode': 'ETB', 'numericCode': '230', 'name': 'Ethiopian birr', 'rate': 0.039050980060122, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 25.607551934943}
# {'code': 'XCD', 'alphaCode': 'XCD', 'numericCode': '951', 'name': 'East Caribbean Dollar', 'rate': 0.0023176148222649, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 431.47808272245}
# {'code': 'LAK', 'alphaCode': 'LAK', 'numericCode': '418', 'name': 'Lao kip', 'rate': 8.2016845339301, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.12192617210075}
# {'code': 'BWP', 'alphaCode': 'BWP', 'numericCode': '072', 'name': 'Botswana Pula', 'rate': 0.0094389158610852, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 105.94437059481}
# {'code': 'KWD', 'alphaCode': 'KWD', 'numericCode': '414', 'name': 'Kuwaiti Dinar', 'rate': 0.00025809462430035, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 3874.5479597293}
# {'code': 'CZK', 'alphaCode': 'CZK', 'numericCode': '203', 'name': 'Czech Koruna', 'rate': 0.018434536547324, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 54.246007076602}
# {'code': 'PGK', 'alphaCode': 'PGK', 'numericCode': '598', 'name': 'Papua New Guinean kina', 'rate': 0.0030169373973098, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 331.46196566481}
# {'code': 'RSD', 'alphaCode': 'RSD', 'numericCode': '941', 'name': 'Serbian Dinar', 'rate': 0.084990038740583, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 11.766084764972}
# {'code': 'GMD', 'alphaCode': 'GMD', 'numericCode': '270', 'name': 'Gambian dalasi', 'rate': 0.04452343032705, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 22.460084334348}
# {'code': 'AWG', 'alphaCode': 'AWG', 'numericCode': '533', 'name': 'Aruban florin', 'rate': 0.0015477072119931, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 646.11703832035}
# {'code': 'AOA', 'alphaCode': 'AOA', 'numericCode': '973', 'name': 'Angolan kwanza', 'rate': 0.54541202150636, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1.8334762721916}
# {'code': 'KHR', 'alphaCode': 'KHR', 'numericCode': '116', 'name': 'Cambodian riel', 'rate': 3.4887762569704, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.28663345721929}
# {'code': 'NOK', 'alphaCode': 'NOK', 'numericCode': '578', 'name': 'Norwegian Krone', 'rate': 0.0074625880101422, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 134.00176971326}
# {'code': 'MAD', 'alphaCode': 'MAD', 'numericCode': '504', 'name': 'Moroccan Dirham', 'rate': 0.0075956446136905, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 131.65439549365}
# {'code': 'RON', 'alphaCode': 'RON', 'numericCode': '946', 'name': 'Romanian New Leu', 'rate': 0.0035896855639341, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 278.57593156546}
# {'code': 'BYN', 'alphaCode': 'BYN', 'numericCode': '933', 'name': 'Belarussian Ruble', 'rate': 0.0021652026921768, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 461.85052494769}
# {'code': 'CLP', 'alphaCode': 'CLP', 'numericCode': '152', 'name': 'Chilean Peso', 'rate': 0.66804858870066, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1.4968971073571}
# {'code': 'BSD', 'alphaCode': 'BSD', 'numericCode': '044', 'name': 'Bahamian Dollar', 'rate': 0.0008558167605623, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1168.4744282678}
# {'code': 'DJF', 'alphaCode': 'DJF', 'numericCode': '262', 'name': 'Djiboutian franc', 'rate': 0.15222216620328, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 6.5693454832628}
# {'code': 'HNL', 'alphaCode': 'HNL', 'numericCode': '340', 'name': 'Honduran Lempira', 'rate': 0.020414673294062, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 48.984374405388}
# {'code': 'SCR', 'alphaCode': 'SCR', 'numericCode': '690', 'name': 'Seychelles rupee', 'rate': 0.011059385363427, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 90.42093815692}
# {'code': 'BHD', 'alphaCode': 'BHD', 'numericCode': '048', 'name': 'Bahrain Dinar', 'rate': 0.00032337465059042, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 3092.388343286}
# {'code': 'OMR', 'alphaCode': 'OMR', 'numericCode': '512', 'name': 'Omani Rial', 'rate': 0.00033038855718959, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 3026.7392082412}
# {'code': 'RUB', 'alphaCode': 'RUB', 'numericCode': '643', 'name': 'Russian Rouble', 'rate': 0.06303992629721, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 15.862962708512}
# {'code': 'LYD', 'alphaCode': 'LYD', 'numericCode': '434', 'name': 'Libyan Dinar', 'rate': 0.0038620225032593, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 258.93168648191}
# {'code': 'UYU', 'alphaCode': 'UYU', 'numericCode': '858', 'name': 'Uruguayan Peso', 'rate': 0.036447796086449, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 27.436501170829}
# {'code': 'FJD', 'alphaCode': 'FJD', 'numericCode': '242', 'name': 'Fiji Dollar', 'rate': 0.0017874547351093, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 559.45472652143}
# {'code': 'CDF', 'alphaCode': 'CDF', 'numericCode': '976', 'name': 'Congolese franc', 'rate': 1.6982211359824, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.58885146275224}
# {'code': 'LSL', 'alphaCode': 'LSL', 'numericCode': '426', 'name': 'Lesotho loti', 'rate': 0.012353613171152, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 80.94797741726}
# {'code': 'TZS', 'alphaCode': 'TZS', 'numericCode': '834', 'name': 'Tanzanian shilling', 'rate': 1.9833164418413, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.5042059748527}
# {'code': 'BBD', 'alphaCode': 'BBD', 'numericCode': '052', 'name': 'Barbadian Dollar', 'rate': 0.0017205270044099, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 581.21726508034}
# {'code': 'BDT', 'alphaCode': 'BDT', 'numericCode': '050', 'name': 'Bangladeshi taka', 'rate': 0.072915729839264, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 13.714461916577}
# {'code': 'QAR', 'alphaCode': 'QAR', 'numericCode': '634', 'name': 'Qatari Rial', 'rate': 0.0031263807851325, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 319.85867004924}
# {'code': 'MXN', 'alphaCode': 'MXN', 'numericCode': '484', 'name': 'Mexican Peso', 'rate': 0.017159396866204, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 58.277106578818}
# {'code': 'AMD', 'alphaCode': 'AMD', 'numericCode': '051', 'name': 'Armenia Dram', 'rate': 0.42305779567508, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.3637432289938}
# {'code': 'NIO', 'alphaCode': 'NIO', 'numericCode': '558', 'name': 'Nicaraguan Córdoba', 'rate': 0.030119974212356, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 33.200559633606}
# {'code': 'LRD', 'alphaCode': 'LRD', 'numericCode': '430', 'name': 'Liberian dollar', 'rate': 0.14674762910485, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 6.814420144979}
# {'code': 'SDG', 'alphaCode': 'SDG', 'numericCode': '938', 'name': 'Sudanese pound', 'rate': 0.37614622172851, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.658540594678}
# {'code': 'MRU', 'alphaCode': 'MRU', 'numericCode': '929', 'name': 'Mauritanian ouguiya', 'rate': 0.030901530963533, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 32.360856204183}
# {'code': 'MNT', 'alphaCode': 'MNT', 'numericCode': '496', 'name': 'Mongolian togrog', 'rate': 2.4366881079956, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.41039310559224}
# {'code': 'BRL', 'alphaCode': 'BRL', 'numericCode': '986', 'name': 'Brazilian Real', 'rate': 0.0044460865824272, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 224.91689746943}
# {'code': 'HKD', 'alphaCode': 'HKD', 'numericCode': '344', 'name': 'Hong Kong Dollar', 'rate': 0.0066887254514497, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 149.50531416763}
# {'code': 'THB', 'alphaCode': 'THB', 'numericCode': '764', 'name': 'Thai Baht', 'rate': 0.027913438404323, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 35.825038302882}
# {'code': 'XAF', 'alphaCode': 'XAF', 'numericCode': '950', 'name': 'Central African CFA Franc', 'rate': 0.476361496196, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.0992460725427}
# {'code': 'MDL', 'alphaCode': 'MDL', 'numericCode': '498', 'name': 'Moldova Lei', 'rate': 0.015154159386944, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 65.988483720287}
# {'code': 'UZS', 'alphaCode': 'UZS', 'numericCode': '860', 'name': 'Uzbekistan Sum', 'rate': 9.1489638675039, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.1093019946829}
# {'code': 'PAB', 'alphaCode': 'PAB', 'numericCode': '590', 'name': 'Panamanian Balboa', 'rate': 0.0008558167605623, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1168.4744282678}
# {'code': 'TTD', 'alphaCode': 'TTD', 'numericCode': '780', 'name': 'Trinidad Tobago Dollar', 'rate': 0.005808434733827, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 172.1634219588}
# {'code': 'HTG', 'alphaCode': 'HTG', 'numericCode': '332', 'name': 'Haitian gourde', 'rate': 0.083481431863218, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 11.978711644986}
# {'code': 'CUP', 'alphaCode': 'CUP', 'numericCode': '192', 'name': 'Cuban peso', 'rate': 0.0008558167605623, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1168.4744282678}
# {'code': 'DKK', 'alphaCode': 'DKK', 'numericCode': '208', 'name': 'Danish Krone', 'rate': 0.0053928117595289, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 185.43202407038}
# {'code': 'JOD', 'alphaCode': 'JOD', 'numericCode': '400', 'name': 'Jordanian Dinar', 'rate': 0.00060899890978304, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1642.0390643331}
# {'code': 'BGN', 'alphaCode': 'BGN', 'numericCode': '975', 'name': 'Bulgarian Lev', 'rate': 0.0014183373224815, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 705.05089596772}
# {'code': 'VND', 'alphaCode': 'VND', 'numericCode': '704', 'name': 'Vietnamese Dong', 'rate': 19.533543623147, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.051193988110534}
# {'code': 'IQD', 'alphaCode': 'IQD', 'numericCode': '368', 'name': 'Iraqi dinar', 'rate': 1.2483467520486, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.80105947995532}
# {'code': 'SVC', 'alphaCode': 'SVC', 'numericCode': '222', 'name': 'Salvadoran colon', 'rate': 0.0074850689136278, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 133.59930436704}
# {'code': 'CVE', 'alphaCode': 'CVE', 'numericCode': '132', 'name': 'Cape Verde escudo', 'rate': 0.080207650221524, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 12.467638650903}
# {'code': 'ZMW', 'alphaCode': 'ZMW', 'numericCode': '967', 'name': 'Zambian kwacha', 'rate': 0.013658063977621, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 73.216819136188}
# {'code': 'YER', 'alphaCode': 'YER', 'numericCode': '886', 'name': 'Yemeni rial', 'rate': 0.21402695415553, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 4.6723087003018}
# {'code': 'LKR', 'alphaCode': 'LKR', 'numericCode': '144', 'name': 'Sri Lanka Rupee', 'rate': 0.17153357825824, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 5.8297623716245}
# {'code': 'PLN', 'alphaCode': 'PLN', 'numericCode': '985', 'name': 'Polish Zloty', 'rate': 0.0032768829625488, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 305.16805495616}
# {'code': 'PEN', 'alphaCode': 'PEN', 'numericCode': '604', 'name': 'Peruvian Nuevo Sol', 'rate': 0.003529242849197, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 283.34689414403}
# {'code': 'ARS', 'alphaCode': 'ARS', 'numericCode': '032', 'name': 'Argentine Peso', 'rate': 0.083886881986645, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 11.920814987011}
# {'code': 'STN', 'alphaCode': 'STN', 'numericCode': '930', 'name': 'São Tomé and Príncipe Dobra', 'rate': 0.017921534113024, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 55.798794550366}
# {'code': 'XPF', 'alphaCode': 'XPF', 'numericCode': '953', 'name': 'CFP Franc', 'rate': 0.086424722805703, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 11.570763174424}
# {'code': 'ALL', 'alphaCode': 'ALL', 'numericCode': '008', 'name': 'Albanian lek', 'rate': 0.08826865536597, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 11.329049885873}
# {'code': 'MUR', 'alphaCode': 'MUR', 'numericCode': '480', 'name': 'Mauritian Rupee', 'rate': 0.036199912931838, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 27.624375834354}
# {'code': 'DOP', 'alphaCode': 'DOP', 'numericCode': '214', 'name': 'Dominican Peso', 'rate': 0.048730473181428, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 20.521040218036}
# {'code': 'NZD', 'alphaCode': 'NZD', 'numericCode': '554', 'name': 'New Zealand Dollar', 'rate': 0.0012101918279586, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 826.31528068312}
# {'code': 'HRK', 'alphaCode': 'HRK', 'numericCode': '191', 'name': 'Croatian Kuna', 'rate': 0.0054240985760756, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 184.36243109791}
# {'code': 'DZD', 'alphaCode': 'DZD', 'numericCode': '012', 'name': 'Algerian Dinar', 'rate': 0.11583572310129, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 8.6329154187228}
# {'code': 'PYG', 'alphaCode': 'PYG', 'numericCode': '600', 'name': 'Paraguayan Guaraní', 'rate': 5.9392932218434, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.16837020208435}
# {'code': 'BND', 'alphaCode': 'BND', 'numericCode': '096', 'name': 'Brunei Dollar', 'rate': 0.0011511034960913, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 868.73161570232}
# {'code': 'KMF', 'alphaCode': 'KMF', 'numericCode': '174', 'name': '\tComoro franc', 'rate': 0.35671159025922, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.8033852201811}
# {'code': 'SZL', 'alphaCode': 'SZL', 'numericCode': '748', 'name': 'Swazi lilangeni', 'rate': 0.012353613171152, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 80.94797741726}
# {'code': 'SOS', 'alphaCode': 'SOS', 'numericCode': '706', 'name': 'Somali shilling', 'rate': 0.49463000741206, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.02171316947}
# {'code': 'ANG', 'alphaCode': 'ANG', 'numericCode': '532', 'name': 'Neth. Antillean Guilder', 'rate': 0.0015274586348029, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 654.68221345913}
# {'code': 'PKR', 'alphaCode': 'PKR', 'numericCode': '586', 'name': 'Pakistani Rupee', 'rate': 0.1429097577519, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 6.9974228193433}
# {'code': 'AZN', 'alphaCode': 'AZN', 'numericCode': '944', 'name': 'Azerbaijan Manat', 'rate': 0.0014567688687936, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 686.4506933266}
# {'code': 'CRC', 'alphaCode': 'CRC', 'numericCode': '188', 'name': 'Costa Rican Colón', 'rate': 0.53449955676547, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1.8709089415369}
# {'code': 'JMD', 'alphaCode': 'JMD', 'numericCode': '388', 'name': 'Jamaican Dollar', 'rate': 0.12934672446791, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 7.7311582810748}
# {'code': 'SSP', 'alphaCode': 'SSP', 'numericCode': '728', 'name': 'South Sudanese pound', 'rate': 0.15208775057109, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 6.575151491458}
# {'code': 'ERN', 'alphaCode': 'ERN', 'numericCode': '232', 'name': 'Eritrean nakfa', 'rate': 0.012893901217644, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 77.556046313709}
# {'code': 'WST', 'alphaCode': 'WST', 'numericCode': '882', 'name': 'Samoan tala', 'rate': 0.002183686193139, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 457.94125691775}
# {'code': 'EGP', 'alphaCode': 'EGP', 'numericCode': '818', 'name': 'Egyptian Pound', 'rate': 0.013528610919784, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 73.917418863574}
# {'code': 'SGD', 'alphaCode': 'SGD', 'numericCode': '702', 'name': 'Singapore Dollar', 'rate': 0.0011571295342513, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 864.20748101206}
# {'code': 'ZAR', 'alphaCode': 'ZAR', 'numericCode': '710', 'name': 'South African Rand', 'rate': 0.012311425110795, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 81.225365138533}
# {'code': 'KGS', 'alphaCode': 'KGS', 'numericCode': '417', 'name': 'Kyrgyzstan Som', 'rate': 0.072664415972595, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 13.761894135049}
# {'code': 'TMT', 'alphaCode': 'TMT', 'numericCode': '934', 'name': 'New Turkmenistan Manat', 'rate': 0.0029991112770111, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 333.43210959368}
# {'code': 'MGA', 'alphaCode': 'MGA', 'numericCode': '969', 'name': 'Malagasy ariary', 'rate': 3.352942755162, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.29824547360985}
# {'code': 'SRD', 'alphaCode': 'SRD', 'numericCode': '968', 'name': 'Surinamese dollar', 'rate': 0.018405355056457, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 54.332013532615}
# {'code': 'GHS', 'alphaCode': 'GHS', 'numericCode': '936', 'name': 'Ghanaian Cedi', 'rate': 0.0051648865672949, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 193.61509434345}
# {'code': 'MOP', 'alphaCode': 'MOP', 'numericCode': '446', 'name': 'Macanese pataca', 'rate': 0.0068533447728546, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 145.91415332859}
# {'code': 'BAM', 'alphaCode': 'BAM', 'numericCode': '977', 'name': 'Bosnia and Herzegovina convertible mark', 'rate': 0.0014200356385499, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 704.20767821094}
# {'code': 'INR', 'alphaCode': 'INR', 'numericCode': '356', 'name': 'Indian Rupee', 'rate': 0.063180021353535, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 15.827788256106}
# {'code': 'TRY', 'alphaCode': 'TRY', 'numericCode': '949', 'name': 'Turkish Lira', 'rate': 0.0071702448053744, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 139.46525218364}
# {'code': 'TWD', 'alphaCode': 'TWD', 'numericCode': '901', 'name': 'New Taiwan Dollar ', 'rate': 0.023773824204503, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 42.06306866737}
# {'code': 'IRR', 'alphaCode': 'IRR', 'numericCode': '364', 'name': 'Iranian rial', 'rate': 35.918544173402, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.027840772030524}
# {'code': 'VES', 'alphaCode': 'VES', 'numericCode': '928', 'name': 'Venezuelan Bolivar', 'rate': 3518.7872355249, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.00028418882218971}
# {'code': 'SBD', 'alphaCode': 'SBD', 'numericCode': '090', 'name': 'Solomon Islands dollar', 'rate': 0.006819070908602, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 146.64754383747}
# {'code': 'MWK', 'alphaCode': 'MWK', 'numericCode': '454', 'name': 'Malawian kwacha', 'rate': 0.69479238408453, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1.4392788736705}
# {'code': 'GTQ', 'alphaCode': 'GTQ', 'numericCode': '320', 'name': 'Guatemalan Quetzal', 'rate': 0.0066164013931221, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 151.13956070433}
# {'code': 'LBP', 'alphaCode': 'LBP', 'numericCode': '422', 'name': 'Lebanese Pound', 'rate': 1.2910126788522, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.77458573132612}
# {'code': 'HUF', 'alphaCode': 'HUF', 'numericCode': '348', 'name': 'Hungarian Forint', 'rate': 0.25256397283425, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 3.959392896691}
# {'code': 'NGN', 'alphaCode': 'NGN', 'numericCode': '566', 'name': 'Nigerian Naira', 'rate': 0.35223702181118, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 2.8389974309289}
# {'code': 'GEL', 'alphaCode': 'GEL', 'numericCode': '981', 'name': 'Georgian lari', 'rate': 0.0026589463942476, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 376.08881554115}
# {'code': 'MKD', 'alphaCode': 'MKD', 'numericCode': '807', 'name': 'Macedonian denar', 'rate': 0.044624822781531, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 22.409052578106}
# {'code': 'BIF', 'alphaCode': 'BIF', 'numericCode': '108', 'name': 'Burundian franc', 'rate': 1.6973403158912, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.58915704213092}
# {'code': 'MMK', 'alphaCode': 'MMK', 'numericCode': '104', 'name': 'Myanma Kyat', 'rate': 1.40751489421, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 0.71047205547426}
# {'code': 'MVR', 'alphaCode': 'MVR', 'numericCode': '462', 'name': 'Maldivian rufiyaa', 'rate': 0.013216769503385, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 75.661454165775}
# {'code': 'SEK', 'alphaCode': 'SEK', 'numericCode': '752', 'name': 'Swedish Krona', 'rate': 0.0073749462111487, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 135.59420928227}
# {'code': 'NPR', 'alphaCode': 'NPR', 'numericCode': '524', 'name': 'Nepalese Rupee', 'rate': 0.10028978966723, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 9.9711047686716}
# {'code': 'ISK', 'alphaCode': 'ISK', 'numericCode': '352', 'name': 'Icelandic Krona', 'rate': 0.10937377307483, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 9.1429597049364}
# {'code': 'GIP', 'alphaCode': 'GIP', 'numericCode': '292', 'name': 'Gibraltar pound', 'rate': 0.00062200283932689, 'date': 'Tue, 7 Sep 2021 23:55:01 GMT', 'inverseRate': 1607.7097028724}

# %% [markdown]
# ## 환율 정보에서 `code`와 `rate`만 추출하여 출력하기
# __Sample Run:__
# ```
# USD 0.00086484208312665
# EUR 0.00072856130060557
# GBP 0.00062543395312534
# JPY 0.09507474341514
# AUD 0.0011633915091951
# ...
# ```

# %%
for item in rates:
    code = rates[item]['code']
    rate = rates[item]['rate']
    print(code, rate)
# Out:
# USD 0.00086024871297761
# EUR 0.00072558820750023
# GBP 0.00062380494854346
# CAD 0.0010843434617936
# JPY 0.094734588344729
# AUD 0.0011631982603228
# CHF 0.00078855420624272
# COP 3.2513069501533
# BZD 0.0017235330115543
# GNF 8.3694939361587
# SLL 8.8445192676703
# KES 0.093971747330519
# AED 0.0031458180338181
# PHP 0.043192181334159
# ILS 0.0027575518835112
# MRO 0.031192581970241
# BOB 0.005902549287063
# GYD 0.17889204225869
# RWF 0.86299370491516
# MZN 0.054815278543352
# UGX 3.0216732493426
# CNY 0.005561077716566
# SAR 0.0032263367920917
# MYR 0.0035682074288339
# KZT 0.36657133209901
# TJS 0.0097168148045556
# AFN 0.075955624571489
# NAD 0.012353613171152
# SYP 2.1816480860254
# TOP 0.001922947543212
# VUV 0.094804801235239
# IDR 12.21447396309
# TND 0.0023810819904794
# XOF 0.47613312091382
# UAH 0.022998025264125
# ETB 0.039050980060122
# XCD 0.0023176148222649
# LAK 8.2016845339301
# BWP 0.0094389158610852
# KWD 0.00025809462430035
# CZK 0.018434536547324
# PGK 0.0030169373973098
# RSD 0.084990038740583
# GMD 0.04452343032705
# AWG 0.0015477072119931
# AOA 0.54541202150636
# KHR 3.4887762569704
# NOK 0.0074625880101422
# MAD 0.0075956446136905
# RON 0.0035896855639341
# BYN 0.0021652026921768
# CLP 0.66804858870066
# BSD 0.0008558167605623
# DJF 0.15222216620328
# HNL 0.020414673294062
# SCR 0.011059385363427
# BHD 0.00032337465059042
# OMR 0.00033038855718959
# RUB 0.06303992629721
# LYD 0.0038620225032593
# UYU 0.036447796086449
# FJD 0.0017874547351093
# CDF 1.6982211359824
# LSL 0.012353613171152
# TZS 1.9833164418413
# BBD 0.0017205270044099
# BDT 0.072915729839264
# QAR 0.0031263807851325
# MXN 0.017159396866204
# AMD 0.42305779567508
# NIO 0.030119974212356
# LRD 0.14674762910485
# SDG 0.37614622172851
# MRU 0.030901530963533
# MNT 2.4366881079956
# BRL 0.0044460865824272
# HKD 0.0066887254514497
# THB 0.027913438404323
# XAF 0.476361496196
# MDL 0.015154159386944
# UZS 9.1489638675039
# PAB 0.0008558167605623
# TTD 0.005808434733827
# HTG 0.083481431863218
# CUP 0.0008558167605623
# DKK 0.0053928117595289
# JOD 0.00060899890978304
# BGN 0.0014183373224815
# VND 19.533543623147
# IQD 1.2483467520486
# SVC 0.0074850689136278
# CVE 0.080207650221524
# ZMW 0.013658063977621
# YER 0.21402695415553
# LKR 0.17153357825824
# PLN 0.0032768829625488
# PEN 0.003529242849197
# ARS 0.083886881986645
# STN 0.017921534113024
# XPF 0.086424722805703
# ALL 0.08826865536597
# MUR 0.036199912931838
# DOP 0.048730473181428
# NZD 0.0012101918279586
# HRK 0.0054240985760756
# DZD 0.11583572310129
# PYG 5.9392932218434
# BND 0.0011511034960913
# KMF 0.35671159025922
# SZL 0.012353613171152
# SOS 0.49463000741206
# ANG 0.0015274586348029
# PKR 0.1429097577519
# AZN 0.0014567688687936
# CRC 0.53449955676547
# JMD 0.12934672446791
# SSP 0.15208775057109
# ERN 0.012893901217644
# WST 0.002183686193139
# EGP 0.013528610919784
# SGD 0.0011571295342513
# ZAR 0.012311425110795
# KGS 0.072664415972595
# TMT 0.0029991112770111
# MGA 3.352942755162
# SRD 0.018405355056457
# GHS 0.0051648865672949
# MOP 0.0068533447728546
# BAM 0.0014200356385499
# INR 0.063180021353535
# TRY 0.0071702448053744
# TWD 0.023773824204503
# IRR 35.918544173402
# VES 3518.7872355249
# SBD 0.006819070908602
# MWK 0.69479238408453
# GTQ 0.0066164013931221
# LBP 1.2910126788522
# HUF 0.25256397283425
# NGN 0.35223702181118
# GEL 0.0026589463942476
# MKD 0.044624822781531
# BIF 1.6973403158912
# MMK 1.40751489421
# MVR 0.013216769503385
# SEK 0.0073749462111487
# NPR 0.10028978966723
# ISK 0.10937377307483
# GIP 0.00062200283932689

# %% [markdown]
# ## `code`를 key, `rate`를 value로 하는 dict type의 `krw_rates` 만들기
# - 위의 코드를 수정하여 새로운 dict type의 객체 `krw_rates`를 만들어 `key`로 `rate`를 쉽게 찾는데 활용하려고 합니다.
# - 즉 `krw_rates['USD']`의 형식을 사용하여 환율 정보를 쉽게 접근할 수 있도록 하는 작업입니다.
# - 다른 말로, 위에서 출력해본 `code, rate` 정보를 모두 `krw_rates`에 저장하는 것입니다.
#
# __Sample Run:__
# ```
# 0.00086484208312665
# 0.00072856130060557
# 0.09507474341514
# 0.001084071583917
# ```

# %%
krw_rates = dict()   # empty name in dict type 

for item in rates:
    code = rates[item]['code']
    rate = rates[item]['rate']
    krw_rates[code] = rate

print('USD:', krw_rates['USD']) 
print('EUR:', krw_rates['EUR'])
print('JPY:', krw_rates['JPY'])
print('CAD:', krw_rates['CAD'])
# Out:
# USD: 0.00086024871297761
# EUR: 0.00072558820750023
# JPY: 0.094734588344729
# CAD: 0.0010843434617936

# %% [markdown]
# ## 환율 계산 하기
# 거의 다 했습니다. 이제 환율을 계산해봅니다. 여기서 제공되는 환율은 Korean Won(KRW)으로 1원에 대한 다른 통화의 가격입니다. 그러므로, 대개 숫자가 낮은 값으로 출력됨으로, 1000원에 대한 환율을 계산하여 봅시다.
# - `krw_rates[]`로 출력되는 값들은 모두 문자열(`str`) 타입이므로 `float()`로 변환하는 것이 필요합니다.
#
# __Sample Run:__
# ```
# 0.86484208312665
# 0.72856130060557
# 95.07474341513999
# 1.084071583917
# ```

# %%
#print(type(krw_rates['USD']))
print(krw_rates['USD']*1000) 
print(krw_rates['EUR']*1000)
print(krw_rates['JPY']*1000)
print(krw_rates['CAD']*1000)
# Out:
# 0.86024871297761
# 0.72558820750023
# 94.734588344729
# 1.0843434617936

# %% [markdown]
# ## 환율 정보에서 `date`를 추출하여 `krw_rates`에 추가하기
# - 환율 정보에서 빼놓을 수 없는 정보는 `date`입니다. `rate`와 더불어 `date`정보를 추가하려고 합니다. `krw_rates`의 `key`는 변함없이 각 통화 `code`값들(e.g. 'USD', 'EUR', etc.)이지만, `value`로 `rate`뿐만 아니라 `date`를 포함하여 정보를 유지관리하고 보호하려고 합니다. 다음과 같은 dict type을 만들려고 하는 것입니다. 이것을 어떻게 구현할 수 있겠습니까?
#
# ```
# {
#   'USD': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00086484208312665'),
#   'EUR': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00072856130060557'),
#  ...
# }
# ```
# 값이 여러 개일 경우에는 list, tuple, dict types을 사용하여 하나로 묶어야 합니다. 자료를 수정하지 아니하도록 여기서는 tuple을 사용하도록 합니다.
#
# __Sample Run:__
# ```
# Sat, 4 Sep 2021 23:55:01 GMT 0.86484208312665
# Sat, 4 Sep 2021 23:55:01 GMT 0.72856130060557
# Sat, 4 Sep 2021 23:55:01 GMT 95.07474341513999
# Sat, 4 Sep 2021 23:55:01 GMT 1.084071583917
# ```

# %%
krw_rates = dict()   # empty name in dict type 

for name in rates:
    date = rates[name]['date']
    code = rates[name]['code']
    rate = rates[name]['rate']
    krw_rates[code] = (date,rate)
    
print(krw_rates['USD'][0],krw_rates['USD'][1]*1000) 
print(krw_rates['EUR'][0],krw_rates['EUR'][1]*1000)
print(krw_rates['JPY'][0],krw_rates['JPY'][1]*1000)
print(krw_rates['CAD'][0],krw_rates['CAD'][1]*1000)
# Out:
# Tue, 7 Sep 2021 23:55:01 GMT 0.86024871297761
# Tue, 7 Sep 2021 23:55:01 GMT 0.72558820750023
# Tue, 7 Sep 2021 23:55:01 GMT 94.734588344729
# Tue, 7 Sep 2021 23:55:01 GMT 1.0843434617936

# %% [markdown]
# --------
# 슬기로운 자는 재앙을 보면 숨어 피하여도 어리석은 자들은 나가다가 해를 받느니라.
# 잠언22:3, 27:12
